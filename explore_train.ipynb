# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/workspace/datasets/train.csv") # Load up our query logs
df
# Out:
#                                              user      sku  \
# 0        000000df17cd56a5df4a94074e133c9d4739fae3  2125233
# 1        000001928162247ffaf63185cd8b2a244c78e7c6  2009324
# 2        000017f79c2b5da56721f22f9fdd726b13daf8e8  1517163
# 3        000017f79c2b5da56721f22f9fdd726b13daf8e8  2877125
# 4        000017f79c2b5da56721f22f9fdd726b13daf8e8  2877134
# ...                                           ...      ...
# 1865264  ffffbcfcee8ff636231fa0df557528e6fa2ecdba  3674224
# 1865265  ffffddbbdc67c4d775c7232082adaf40c7e7d03c  2986037
# 1865266  ffffed824a4fc5b78e407a423f72bbbc2f6e5213  3303069
# 1865267  fffff158dec2f40d082f7797413f7b6dbc1713e6  2390524
# 1865268  fffff53f46ee78433a09fada9439848fdf0e3a9b  3504376
#
#                    category                                query  \
# 0              abcat0101001  Televisiones Panasonic  50 pulgadas
# 1              abcat0101001                                Sharp
# ...

# %%
gb = df.groupby("query") # Group on query

# %%
gb.first()
# Out:
#                                                                                         user  \
# query
# !pod                                                ee0c57592de376bf9e687eaab46c05f6d8e15988
# #                                                   0240c3e637c81f402565ce97978c032b2f6454f3
# # 1 hits of the 50s                                 22ee0cd6a6dce1df2f5487ed6a6faa6b78c8fb06
# # TC-P50GT30                                        144d310cedd839dc33d5dddc8847b90a1347b048
# #1 Girl                                             e9fbedbfa8d6d3309b00871185a73aa40019321c
# ...                                                                                      ...
# ��Mfr: SONY ��Model: VPCYB/15KX/P �� ��UPC: 027...  1b4cd9dccc522a5aa0ef1e146c5277ce704c821e
# ��Mfr: TOSHIBA ��Model: BDX4200 ��                  28e001b8f0605e7b3a2eac7ec21c80ea10af3488
# ��Model: U30JCB2B                                   d512aff4d504f12273f069830226aac45ed8b432
# ...

# %%
gb.get_group("ipad").count() #how many clicks did the ipad query receive?
# Out:
# user          5036
# sku           5036
# category      5036
# query         5036
# click_time    5036
# query_time    5036
# dtype: int64

# %%
df[df["category"] == "abcat0101001"] # Get all queries in the given category
# Out:
#                                              user      sku      category  \
# 0        000000df17cd56a5df4a94074e133c9d4739fae3  2125233  abcat0101001
# 1        000001928162247ffaf63185cd8b2a244c78e7c6  2009324  abcat0101001
# 3        000017f79c2b5da56721f22f9fdd726b13daf8e8  2877125  abcat0101001
# 19       0000c4e9d7075985d1020c456e7ce36f83f834eb  2126065  abcat0101001
# 40       00017f7beeac02736c0ce7bf1e75f3010939b34e  1831054  abcat0101001
# ...                                           ...      ...           ...
# 1865071  fff7afecf87f8043ce4b4fcbd8ed47d7ffd52679  2620821  abcat0101001
# 1865077  fff7edfacf2c376fa8ea4f637c33013d057ae70a  1854328  abcat0101001
# 1865119  fff97c95234212c39d6f04c9854fa94d94bc0cce  1854819  abcat0101001
# 1865190  fffc750c85c62fe732b8223d5872be6e0fc03593  2262074  abcat0101001
# 1865224  fffd4ebf04febc87ca4b34c730c78d7bf1bef564  2620821  abcat0101001
#
#                                            query               click_time  \
# ...

# %%
df.sample(n=100) # Take a random subsample (your results will differ since this is random)
# Out:
#                                              user      sku  \
# 1027048  8d14bf891397643883d1ac782aa37181cb18cd8b  2061068
# 946224   820bdc144541ccffc1792ed658eb7320de34a770  1678271
# 625910   560e83b03b00e10faa4d6a9a7a0a1891376cbb9d  3142315
# 1466679  c947e822a294b362757472c952eb2d48508f5b08  2193948
# 981404   86da803ac67ce1a1ab7f61b88bc01fb44ffbfc6b  2817582
# ...                                           ...      ...
# 1033138  8de5e7b9539e78af62e2b5f69b33960150758f59  2759694
# 1132717  9b854f3ec1818ea7369fb5808ff688799fb7c500  9225411
# 857433   75e847693879fbd5e0533230da4ca7568225f933  2670179
# 1625668  df12eb6b2dcf45bbce99b29c1bfd01320f0e75c9  3143987
# 485192   42b49db4cf97ab823b524be80f0772db563977c6  1671848
#
#                    category                    query               click_time  \
# 1027048        abcat0401004                  cameras  2011-09-08 09:31:11.504
# 946224         abcat0503002           linksys router  2011-10-26 00:48:38.057
# ...

# %%
# Note: Var named lte (less than or equal to) but code is lt (less than)
lte2 = gb.size().sort_values() < 2

# %%
lte2
# Out:
# query
# !pod                                        True
# Wireless Kit                                True
# Wireless LAN adapters                       True
# Wireless LAN adaptor                        True
# Wireless Microphone                         True
#                                            ...
# hp touchpad                                False
# iPad                                       False
# Hp touchpad                                False
# 2622037 2127204 2127213 2121716 2138291    False
# lcd tv                                     False
# Length: 257860, dtype: bool

# %%
lte2.value_counts()
# Out:
# True     165490
# False     92370
# dtype: int64

# %%
txgb = pd.read_csv("/workspace/ltr_output/training.xgb", sep='\t', header=None)

# %%
txgb
# Out:
#         0         1          2          3            4            5  \
# 0     1.0  qid:1558   1:9.8636   2:9.8636   3:236.0000    4:50.9900
# 1     1.0   qid:388   1:3.4492   2:3.4492  3:1230.0000   4:249.9900
# 2     0.0   qid:967   1:0.0000   2:0.0000     3:5.0000    4:59.9900
# 3     0.5   qid:645  1:20.0119  2:20.0120   3:150.0000    4:34.9900
# 4     0.5  qid:2224   1:6.4109   2:6.4109  3:3781.0000   4:329.9900
# ...   ...       ...        ...        ...          ...          ...
# 8756  1.0  qid:2455   1:4.1351   2:4.1351  3:1604.0000  4:1099.9900
# 8757  0.0  qid:3029   1:6.0667   2:0.0000  3:1653.0000   4:449.9900
# 8758  0.5  qid:2756   1:7.2358   2:0.0000   3:177.0000   4:249.9900
# 8759  0.0  qid:2132   1:8.7416   2:8.7416    3:29.0000    4:24.9900
# 8760  0.5   qid:260  1:14.0382  2:14.0382     3:3.0000   4:179.9900
#
#                           6    7                      8     9
# 0       5:50.9900 # 1158136  4.0        Vampire diaries  fake
# ...

# %%
txgb[0].value_counts()
# Out:
# 0.0    3016
# 1.0    2907
# 0.5    2838
# Name: 0, dtype: int64

# %%
# After quantizing
txgb = pd.read_csv("/workspace/ltr_output/training.xgb", sep='\t', header=None)
txgb[0].value_counts()
# Out:
# 0.75    2891
# 0.00    2215
# 1.00    2021
# 0.50    1634
# Name: 0, dtype: int64

# %%
# After downsampling
txgb = pd.read_csv("/workspace/ltr_output/training.xgb", sep='\t', header=None)
txgb[0].value_counts()
# Out:
# 1.00    1634
# 0.00    1634
# 0.50    1634
# 0.75    1634
# Name: 0, dtype: int64
